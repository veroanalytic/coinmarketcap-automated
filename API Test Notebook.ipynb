# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'be418cc8-d60e-4d91-85a8-2bfae177f020',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  # print(data)  # Commented out so I don't get a huge wall of data
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %% [markdown]
# json normalize

# %%
pd.set_option('display.max_columns', None)

# %%
pd.json_normalize(data['data'])
# Out:
#          id            name  symbol            slug  num_market_pairs  \
# 0         1         Bitcoin     BTC         bitcoin              9740
# 1      1027        Ethereum     ETH        ethereum              6089
# 2       825          Tether    USDT          tether             39680
# 3      3408        USD Coin    USDC        usd-coin              6195
# 4      1839             BNB     BNB             bnb              1103
# ...     ...             ...     ...             ...               ...
# 4995  17068  LondonCoinGold    LDXG  londoncoingold                 1
# 4996  14219    Viva Classic    VIVA    viva-classic                 2
# 4997  20065        Nafstars  NSTARS        nafstars                 3
# 4998  21089        CRYPTORG     CTG        cryptorg                 3
# 4999  17969   Heroes of NFT     HON   heroes-of-nft                 2
#
#                     date_added  \
# 0     2013-04-28T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2018-10-08T00:00:00.000Z
# 4     2017-07-25T00:00:00.000Z
# ...                        ...
# 4995  2022-01-10T07:06:17.000Z
# 4996  2021-11-10T04:57:11.000Z
# 4997  2022-05-09T22:25:33.000Z
# 4998  2022-07-22T07:06:52.000Z
# 4999  2022-02-09T06:27:41.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [mineable, pow, smart-contracts, ethereum-ecos...           NaN
# 2     [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3     [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 4     [marketplace, centralized-exchange, payments, ...  2.000000e+08
# ...                                                 ...           ...
# 4995                                                 []  5.000000e+09
# 4996                                                 []  1.000000e+11
# 4997                                                 []  6.000000e+08
# 4998                                                 []  1.000000e+08
# 4999                                                 []  2.000000e+08
#
#       circulating_supply  total_supply  platform  cmc_rank  \
# 0           1.915088e+07  1.915088e+07       NaN         1
# 1           1.223716e+08  1.223716e+08       NaN         2
# 2           6.788344e+10  6.915678e+10       NaN         3
# 3           5.080746e+10  5.080746e+10       NaN         4
# 4           1.613373e+08  1.613373e+08       NaN         5
# ...                  ...           ...       ...       ...
# 4995        0.000000e+00  0.000000e+00       NaN      4996
# 4996        0.000000e+00  5.000000e+10       NaN      4997
# 4997        0.000000e+00  6.000000e+08       NaN      4998
# 4998        0.000000e+00  1.000000e+08       NaN      4999
# 4999        0.000000e+00  2.000000e+08       NaN      5000
#
#       self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                  NaN                       NaN        NaN
# 1                                  NaN                       NaN        NaN
# 2                                  NaN                       NaN        NaN
# 3                                  NaN                       NaN        NaN
# 4                                  NaN                       NaN        NaN
# ...                                ...                       ...        ...
# 4995                       100000000.0              5.002942e+05        NaN
# 4996                               NaN                       NaN        NaN
# 4997                       600000000.0              7.202771e+06        NaN
# 4998                       100000000.0              3.568878e+06        NaN
# 4999                               NaN                       NaN        NaN
#
#                   last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0     2022-09-15T02:16:00.000Z     2.013682e+04          3.780929e+10
# 1     2022-09-15T02:16:00.000Z     1.617735e+03          1.874876e+10
# 2     2022-09-15T02:16:00.000Z     1.000168e+00          5.578518e+10
# 3     2022-09-15T02:16:00.000Z     9.999141e-01          6.043672e+09
# 4     2022-09-15T02:16:00.000Z     2.770753e+02          9.624979e+08
# ...                        ...              ...                   ...
# 4995  2022-09-15T02:16:00.000Z     5.002942e-03          9.948247e+03
# 4996  2022-09-15T02:16:00.000Z     8.485644e-10          9.897081e+03
# 4997  2022-09-15T02:16:00.000Z     1.200462e-02          9.893760e+03
# 4998  2022-09-15T02:16:00.000Z     3.568878e-02          9.887519e+03
# 4999  2022-09-15T02:16:00.000Z     6.312675e-03          9.879632e+03
#
#       quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                        -26.1279                     0.533417
# 1                        -18.7919                     0.600377
# 2                        -21.9937                     0.005756
# 3                        -18.7310                     0.011781
# 4                        -15.3787                     0.090072
# ...                           ...                          ...
# 4995                   13642.5469                   -16.626868
# 4996                      49.5549                    -7.011117
# 4997                     -18.4370                     0.005767
# 4998                     964.3899                     0.018656
# 4999                      -4.6457                     0.263739
#
#       quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                        -1.049512                     4.729932
# 1                         1.933191                    -0.307030
# 2                         0.014423                     0.007740
# 3                        -0.023746                    -0.017640
# 4                        -0.467059                    -1.017653
# ...                            ...                          ...
# 4995                      3.556644                    -9.045688
# 4996                     13.290245                    11.450681
# 4997                     -0.593494                    -2.519623
# 4998                    -12.711335                   -15.318623
# 4999                     -1.333081                    -2.439507
#
#       quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       -16.650621                     -4.890247
# 1                       -15.051060                     20.787190
# 2                         0.000271                      0.037382
# 3                        -0.009470                      0.010169
# 4                       -13.557217                     11.750365
# ...                            ...                           ...
# 4995                    -13.756663                    -73.509953
# 4996                    -34.836877                    -12.320380
# 4997                    -20.379563                    -66.345802
# 4998                    -31.016386                      2.875832
# 4999                    -29.891805                    -14.547475
#
#       quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                        -3.558779          3.856379e+11
# 1                        46.745578          1.979648e+11
# 2                         0.136976          6.789487e+10
# 3                        -0.053926          5.080309e+10
# 4                        28.120617          4.470257e+10
# ...                            ...                   ...
# 4995                    -94.992050          0.000000e+00
# 4996                    -31.540395          0.000000e+00
# 4997                    -66.220832          0.000000e+00
# 4998                      2.875832          0.000000e+00
# 4999                     -2.245620          0.000000e+00
#
#       quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            38.8039                        4.228732e+11
# 1                            19.9234                        1.979648e+11
# 2                             6.8302                        6.916842e+10
# 3                             5.1129                        5.080309e+10
# 4                             4.4971                        5.541506e+10
# ...                              ...                                 ...
# 4995                          0.0000                        2.501471e+07
# 4996                          0.0000                        8.486000e+01
# 4997                          0.0000                        7.202771e+06
# 4998                          0.0000                        3.568878e+06
# 4999                          0.0000                        1.262535e+06
#
#       quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0               NaN  2022-09-15T02:16:00.000Z          NaN           NaN
# 1               NaN  2022-09-15T02:16:00.000Z          NaN           NaN
# 2               NaN  2022-09-15T02:16:00.000Z       1027.0      Ethereum
# 3               NaN  2022-09-15T02:16:00.000Z       1027.0      Ethereum
# 4               NaN  2022-09-15T02:16:00.000Z          NaN           NaN
# ...             ...                       ...          ...           ...
# 4995            NaN  2022-09-15T02:16:00.000Z       1027.0      Ethereum
# 4996            NaN  2022-09-15T02:16:00.000Z       1839.0           BNB
# 4997            NaN  2022-09-15T02:16:00.000Z       3890.0       Polygon
# 4998            NaN  2022-09-15T02:16:00.000Z       1839.0           BNB
# 4999            NaN  2022-09-15T02:16:00.000Z       5805.0     Avalanche
#
#      platform.symbol platform.slug                      platform.token_address
# 0                NaN           NaN                                         NaN
# 1                NaN           NaN                                         NaN
# 2                ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                NaN           NaN                                         NaN
# ...              ...           ...                                         ...
# 4995             ETH      ethereum  0x7c0853Ab074f2f17E37c5482DCF6C5F6c1246E8b
# 4996             BNB           bnb  0x32767ca0B39a1261E4bA392A605F7FAB37d059c7
# 4997           MATIC       polygon  0x559f80C6f05322067455DeF52114109150F5F19C
# 4998             BNB           bnb  0x69bFa36D50d92e8985d27E6AA6e685C0325ce7B4
# 4999            AVAX     avalanche  0xEd2b42D3C9c6E97e11755BB37df29B6375ede3EB
#
# [5000 rows x 35 columns]
